# %%
import pandas as pd

# %%
df = pd.read_csv("https://github.com/DataTalksClub/nyc-tlc-data/releases/download/green/green_tripdata_2020-01.csv.gz", nrows=100)

# %%
df.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2019-12-18 15:52:30   2019-12-18 15:54:39                  N
# 1         2  2020-01-01 00:45:58   2020-01-01 00:56:39                  N
# 2         2  2020-01-01 00:41:38   2020-01-01 00:52:49                  N
# 3         1  2020-01-01 00:52:46   2020-01-01 01:14:21                  N
# 4         1  2020-01-01 00:19:57   2020-01-01 00:30:56                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0           1           264           264                5           0.00
# 1           5            66            65                2           1.28
# 2           1           181           228                1           2.47
# 3           1           129           263                2           6.30
# 4           1           210           150                1           2.30
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# ...
